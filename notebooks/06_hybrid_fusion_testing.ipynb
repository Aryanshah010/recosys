# %% [markdown]
# # Hybrid Model Fusion Testing
# Comparing fusion weights and blending CBF and CF models.

# %%
import pandas as pd
import sys
sys.path.append('..')
from engine.hybrid_fusion import HybridRecommender
from engine.content_filter import ContentBasedFilter
from engine.collaborative_filter import CollaborativeFilter

# %% [markdown]
# ## Test Fusion Weights

# %%
# cbf = ContentBasedFilter(movies_df)
# cf = CollaborativeFilter()
# hybrid = HybridRecommender(cbf, cf)
# preds = hybrid.recommend(user_id=1, top_k=10, alpha=0.5)
# display(preds)
