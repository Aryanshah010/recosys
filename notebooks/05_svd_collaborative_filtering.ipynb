# %% [markdown]
# # SVD Collaborative Filtering
# Evaluating the SVD model on validation set.

# %%
import pandas as pd
import pickle
from surprise import Dataset, Reader, accuracy
from surprise.model_selection import train_test_split
import sys
sys.path.append('..')
from engine.collaborative_filter import CollaborativeFilter

# %% [markdown]
# ## Load Pre-trained Model

# %%
with open('../data/processed/svd_model.pkl', 'rb') as f:
    svd_model = pickle.load(f)
print('SVD Model loaded successfully.')

# %% [markdown]
# ## Evaluate Predictions

# %%
# Example prediction
# pred = svd_model.predict(uid=1, iid=1)
# print(pred)
