# %% [markdown]
# # Synthetic User Cohort Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
from IPython.display import display
sys.path.append('..')

profiles_df = pd.read_csv('../data/processed/synthetic_user_profiles.csv')
interactions_df = pd.read_csv('../data/processed/synthetic_interactions.csv')
display(profiles_df.head())
# Out:
#    user_id country gender  occupation cohort_group preferred_languages  \
# 0  1000000   Nepal   Male  IT Student     A_Techie               EN|JA
# 1  1000001   Nepal   Male  IT Student     A_Techie               EN|JA
# 2  1000002   Nepal   Male  IT Student     A_Techie               EN|JA
# 3  1000003   Nepal   Male  IT Student     A_Techie               EN|JA
# 4  1000004   Nepal   Male  IT Student     A_Techie               EN|JA
#
#                              preferred_genres  is_cold_start
# 0  ScienceFiction|Action|Thriller|Documentary          False
# 1  ScienceFiction|Action|Thriller|Documentary          False
# 2  ScienceFiction|Action|Thriller|Documentary          False
# 3  ScienceFiction|Action|Thriller|Documentary          False
# 4  ScienceFiction|Action|Thriller|Documentary          False

# %% [markdown]
# ## Cohort Distribution

# %%
cohort_counts = profiles_df['cohort_group'].value_counts()
plt.figure(figsize=(10, 6))
sns.barplot(x=cohort_counts.index, y=cohort_counts.values)
plt.title('Distribution of Synthetic User Archetypes')
plt.ylabel('Number of Users')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Interaction Analysis by Cohort

# %%
merged_df = interactions_df.merge(profiles_df, left_on='userId', right_on='user_id')
avg_ratings = merged_df.groupby('cohort_group')['rating'].mean().sort_values()
print('Average Rating by Cohort:')
display(avg_ratings.to_frame())
# Out:
# Average Rating by Cohort:
#                 rating
# cohort_group
# A_Techie      3.840103
# D_Localist    3.867725
# B_Mainstream  3.895099
# C_AnimeFan    3.940222
