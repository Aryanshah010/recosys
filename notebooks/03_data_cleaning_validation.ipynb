# %% [markdown]
# # Data Cleaning & Validation
# Validating preprocessing thresholds and analyzing sparsity.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

FIG_DIR = '../results/figures'
ratings_df = pd.read_csv('../data/processed/ratings_final.csv')

# %% [markdown]
# ## Sparsity Analysis

# %%
num_users = ratings_df['user_id'].nunique()
num_movies = ratings_df['item_id'].nunique()
num_ratings = len(ratings_df)

sparsity = 1.0 - (num_ratings / (num_users * num_movies))
print(f'Users: {num_users}')
print(f'Movies: {num_movies}')
print(f'Ratings: {num_ratings}')
print(f'Matrix Sparsity: {sparsity:.4%}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Developer/Thesis/recosys/.venv/lib/python3.14/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %% [markdown]
# ## Interaction Heatmap (Sample)

# %%
sample_users = ratings_df['user_id'].sample(100, random_state=42)
sample_movies = ratings_df['item_id'].sample(100, random_state=42)

sample_df = ratings_df[(ratings_df['user_id'].isin(sample_users)) & (ratings_df['item_id'].isin(sample_movies))]
pivot = sample_df.pivot(index='user_id', columns='item_id', values='rating')

plt.figure(figsize=(12, 8))
sns.heatmap(pivot.isnull(), cbar=False, cmap='viridis')
plt.title('Sparsity Heatmap (Yellow = Missing, Purple = Rated)')
plt.savefig(f'{FIG_DIR}/04_sparsity_analysis.png', bbox_inches='tight')
plt.show()
