# %% [markdown]
# # Qualitative Analysis & Recommendation Examples
# Visualizing specific recommendations for different user types.

# %%
import pandas as pd
import matplotlib.pyplot as plt

FIG_DIR = '../results/figures'

# %% [markdown]
# ## Sample Recommendations

# %%
# Extract top 5 recs from each model for 3 diverse users
# Save visual table to FIG_DIR/11_sample_recommendations.png

# %% [markdown]
# ## Cold-start vs Warm-start

# %%
# Compare performance metrics for users with < 10 interactions vs > 100
# plt.savefig(f'{FIG_DIR}/12_cold_vs_warm_start.png')
