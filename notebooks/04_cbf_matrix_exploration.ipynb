# %% [markdown]
# # Content-Based Filtering Matrix Exploration
# Testing retrieval quality using the CBF matrix.

# %%
import pandas as pd
import numpy as np
import pickle
import sys
sys.path.append('..')
from engine.content_filter import ContentBasedFilter

# %% [markdown]
# ## Load CBF Model & Metadata

# %%
movies_df = pd.read_csv('../data/processed/movies_final.csv')

# Initialize CBF
cbf = ContentBasedFilter(movies_df)
# The matrix might be too large to load entirely here without chunks, but we can load the metadata.
with open('../data/processed/cbf_metadata.pkl', 'rb') as f:
    metadata = pickle.load(f)
print('CBF Metadata loaded.')

# %% [markdown]
# ## Test Nearest Neighbors

# %%
# Assuming there is a method to get similar movies
# example_movie_id = movies_df['item_id'].iloc[0]
# similar = cbf.get_similar_items(example_movie_id, k=5)
# print(similar)
